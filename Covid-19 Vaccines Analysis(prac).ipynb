# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv(r"C:\Users\DELL USER\Downloads\archive (3)\country_vaccinations.csv")
data.head(100)
# Out:
#       country iso_code        date  total_vaccinations  people_vaccinated  \
# 0   Argentina      ARG  2020-12-29               700.0                NaN
# 1   Argentina      ARG  2020-12-30                 NaN                NaN
# 2   Argentina      ARG  2020-12-31             32013.0                NaN
# 3   Argentina      ARG  2021-01-01                 NaN                NaN
# 4   Argentina      ARG  2021-01-02                 NaN                NaN
# ..        ...      ...         ...                 ...                ...
# 95    Belgium      BEL  2021-01-19            137279.0           137068.0
# 96    Belgium      BEL  2021-01-20            151375.0           151080.0
# 97    Belgium      BEL  2021-01-21            163240.0           162945.0
# 98     Brazil      BRA  2021-01-16                 0.0                0.0
# 99     Brazil      BRA  2021-01-17               112.0              112.0
#
#     people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN             15656.0
# 2                       NaN                     NaN             15656.0
# 3                       NaN                     NaN             11070.0
# 4                       NaN                     NaN              8776.0
# ..                      ...                     ...                 ...
# 95                    211.0                 13762.0             13001.0
# 96                    295.0                 14096.0             12222.0
# 97                    295.0                 11865.0             11035.0
# 98                      NaN                     NaN                 NaN
# 99                      NaN                   112.0               112.0
#
#     total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.00                            NaN
# 1                              NaN                            NaN
# 2                             0.07                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
# ..                             ...                            ...
# 95                            1.18                           1.18
# 96                            1.31                           1.30
# 97                            1.41                           1.41
# 98                            0.00                           0.00
# 99                            0.00                           0.00
#
#     people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 0                                   NaN                             NaN
# 1                                   NaN                           346.0
# 2                                   NaN                           346.0
# 3                                   NaN                           245.0
# 4                                   NaN                           194.0
# ..                                  ...                             ...
# 95                                  0.0                          1122.0
# 96                                  0.0                          1055.0
# 97                                  0.0                           952.0
# 98                                  NaN                             NaN
# 99                                  NaN                             1.0
#
#            vaccines                                  source_name  \
# 0         Sputnik V                           Ministry of Health
# 1         Sputnik V                           Ministry of Health
# 2         Sputnik V                           Ministry of Health
# 3         Sputnik V                           Ministry of Health
# 4         Sputnik V                           Ministry of Health
# ..              ...                                          ...
# 95  Pfizer/BioNTech                                    Sciensano
# 96  Pfizer/BioNTech                                    Sciensano
# 97  Pfizer/BioNTech                                    Sciensano
# 98          Sinovac  Regional governments via Coronavirus Brasil
# 99          Sinovac  Regional governments via Coronavirus Brasil
#
#                                        source_website
# 0   http://datos.salud.gob.ar/dataset/vacunas-cont...
# 1   http://datos.salud.gob.ar/dataset/vacunas-cont...
# 2   http://datos.salud.gob.ar/dataset/vacunas-cont...
# 3   http://datos.salud.gob.ar/dataset/vacunas-cont...
# 4   http://datos.salud.gob.ar/dataset/vacunas-cont...
# ..                                                ...
# 95  https://datastudio.google.com/embed/u/0/report...
# 96  https://datastudio.google.com/embed/u/0/report...
# 97  https://datastudio.google.com/embed/u/0/report...
# 98                 https://coronavirusbra1.github.io/
# 99                 https://coronavirusbra1.github.io/
#
# [100 rows x 15 columns]

# %%
data.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        8.730000e+02       8.420000e+02             1.980000e+02
# mean         5.636304e+05       5.276886e+05             1.601797e+05
# std          1.755851e+06       1.590297e+06             3.869539e+05
# min          0.000000e+00       0.000000e+00             2.000000e+00
# 25%          1.498000e+04       1.458950e+04             1.952750e+03
# 50%          6.075300e+04       5.859850e+04             8.362000e+03
# 75%          2.688810e+05       2.697472e+05             2.268938e+05
# max          1.910796e+07       1.624309e+07             2.756953e+06
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            7.000000e+02         1266.000000
# mean             4.517910e+04        42295.565561
# std              1.224248e+05       110200.570930
# min              0.000000e+00            1.000000
# 25%              1.694750e+03         1645.250000
# 50%              7.550000e+03         5541.000000
# 75%              3.789650e+04        27979.750000
# max              1.561585e+06       975540.000000
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                      873.000000                     842.000000
# mean                         2.343036                       2.219632
# std                          4.876530                       4.408774
# min                          0.000000                       0.000000
# 25%                          0.210000                       0.220000
# 50%                          0.750000                       0.770000
# 75%                          1.840000                       1.847500
# max                         38.830000                      28.440000
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# count                           198.000000                     1266.000000
# mean                              0.631566                     1421.934439
# std                               1.427802                     3120.611680
# min                               0.000000                        0.000000
# 25%                               0.010000                      261.250000
# 50%                               0.060000                      628.000000
# 75%                               0.687500                     1065.000000
# max                              10.390000                    30869.000000

# %%
pd.to_datetime(data.date)
data.country.value_counts()
# Out:
# Northern Ireland        40
# Canada                  40
# Wales                   40
# Scotland                40
# China                   37
# Israel                  35
# United States           34
# England                 33
# United Kingdom          33
# Switzerland             30
# Chile                   30
# Russia                  30
# Mexico                  30
# Bahrain                 29
# Lithuania               29
# Italy                   27
# Czechia                 27
# Norway                  26
# Germany                 26
# Romania                 26
# Estonia                 26
# Greece                  26
# Portugal                26
# Denmark                 26
# Latvia                  26
# Hungary                 25
# Belgium                 25
# Poland                  25
# Argentina               25
# Bulgaria                25
# Malta                   25
# Iceland                 24
# Luxembourg              23
# Oman                    23
# Costa Rica              23
# Finland                 23
# Sweden                  22
# Croatia                 21
# Ireland                 21
# Austria                 19
# Slovenia                19
# Spain                   19
# France                  19
# Slovakia                18
# United Arab Emirates    18
# Netherlands             17
# Serbia                  14
# Gibraltar               12
# Saudi Arabia            12
# Seychelles              12
# Turkey                  11
# Cyprus                  10
# India                    8
# Brazil                   8
# Isle of Man              2
# Singapore                2
# Kuwait                   1
# Name: country, dtype: int64

# %%
data=data[data.country.apply(lambda x: x not in ["Scotland","Wales","Northern Ireland","England"])]

# %%
#data = data[data.country.apply(lambda x: x not in ["England", "Scotland", "Wales", "Northern Ireland"])]

# %%
data.country.value_counts()
# Out:
# Canada                  40
# China                   37
# Israel                  35
# United States           34
# United Kingdom          33
# Mexico                  30
# Russia                  30
# Chile                   30
# Switzerland             30
# Bahrain                 29
# Lithuania               29
# Czechia                 27
# Italy                   27
# Denmark                 26
# Romania                 26
# Norway                  26
# Portugal                26
# Greece                  26
# Latvia                  26
# Germany                 26
# Estonia                 26
# Poland                  25
# Belgium                 25
# Bulgaria                25
# Argentina               25
# Hungary                 25
# Malta                   25
# Iceland                 24
# Oman                    23
# Finland                 23
# Costa Rica              23
# Luxembourg              23
# Sweden                  22
# Ireland                 21
# Croatia                 21
# Spain                   19
# Slovenia                19
# France                  19
# Austria                 19
# United Arab Emirates    18
# Slovakia                18
# Netherlands             17
# Serbia                  14
# Gibraltar               12
# Seychelles              12
# Saudi Arabia            12
# Turkey                  11
# Cyprus                  10
# India                    8
# Brazil                   8
# Isle of Man              2
# Singapore                2
# Kuwait                   1
# Name: country, dtype: int64

# %%
data.vaccines.value_counts()
# Out:
# Pfizer/BioNTech                        667
# Moderna, Pfizer/BioNTech               267
# Sputnik V                               55
# Pfizer/BioNTech, Sinopharm              47
# CNBG, Sinovac                           37
# Oxford/AstraZeneca, Pfizer/BioNTech     33
# Pfizer/BioNTech, Pifzer/BioNTech        25
# Sinovac                                 19
# Sinopharm                               12
# Covaxin, Covishield                      8
# Name: vaccines, dtype: int64

# %%
df=data[["vaccines","country"]]

# %%
df.head(50)
# Out:
#                       vaccines    country
# 0                    Sputnik V  Argentina
# 1                    Sputnik V  Argentina
# 2                    Sputnik V  Argentina
# 3                    Sputnik V  Argentina
# 4                    Sputnik V  Argentina
# 5                    Sputnik V  Argentina
# 6                    Sputnik V  Argentina
# 7                    Sputnik V  Argentina
# 8                    Sputnik V  Argentina
# 9                    Sputnik V  Argentina
# 10                   Sputnik V  Argentina
# 11                   Sputnik V  Argentina
# 12                   Sputnik V  Argentina
# 13                   Sputnik V  Argentina
# 14                   Sputnik V  Argentina
# 15                   Sputnik V  Argentina
# 16                   Sputnik V  Argentina
# 17                   Sputnik V  Argentina
# 18                   Sputnik V  Argentina
# 19                   Sputnik V  Argentina
# 20                   Sputnik V  Argentina
# 21                   Sputnik V  Argentina
# 22                   Sputnik V  Argentina
# 23                   Sputnik V  Argentina
# 24                   Sputnik V  Argentina
# 25             Pfizer/BioNTech    Austria
# 26             Pfizer/BioNTech    Austria
# 27             Pfizer/BioNTech    Austria
# 28             Pfizer/BioNTech    Austria
# 29             Pfizer/BioNTech    Austria
# 30             Pfizer/BioNTech    Austria
# 31             Pfizer/BioNTech    Austria
# 32             Pfizer/BioNTech    Austria
# 33             Pfizer/BioNTech    Austria
# 34             Pfizer/BioNTech    Austria
# 35             Pfizer/BioNTech    Austria
# 36             Pfizer/BioNTech    Austria
# 37             Pfizer/BioNTech    Austria
# 38             Pfizer/BioNTech    Austria
# 39             Pfizer/BioNTech    Austria
# 40             Pfizer/BioNTech    Austria
# 41             Pfizer/BioNTech    Austria
# 42             Pfizer/BioNTech    Austria
# 43             Pfizer/BioNTech    Austria
# 44  Pfizer/BioNTech, Sinopharm    Bahrain
# 45  Pfizer/BioNTech, Sinopharm    Bahrain
# 46  Pfizer/BioNTech, Sinopharm    Bahrain
# 47  Pfizer/BioNTech, Sinopharm    Bahrain
# 48  Pfizer/BioNTech, Sinopharm    Bahrain
# 49  Pfizer/BioNTech, Sinopharm    Bahrain

# %%
dict_={}
for i in df.vaccines.unique():
    dict_[i]=[df["country"][j]for j in df[df["vaccines"]==i].index]
vaccines={}
for key,value in dict_.items():
    vaccines[key]=set(value)
for i,j in vaccines.items():
    print(f"{i}:>>{j}")
# Out:
# Sputnik V:>>{'Argentina', 'Russia'}
# Pfizer/BioNTech:>>{'Gibraltar', 'Belgium', 'Portugal', 'Austria', 'Singapore', 'Costa Rica', 'Isle of Man', 'Slovenia', 'Malta', 'Slovakia', 'Croatia', 'Estonia', 'Poland', 'Luxembourg', 'Romania', 'Italy', 'Israel', 'Saudi Arabia', 'Finland', 'Ireland', 'France', 'Serbia', 'Cyprus', 'Kuwait', 'Switzerland', 'Greece', 'Norway', 'Oman', 'Latvia', 'Sweden', 'Chile', 'Mexico'}
# Pfizer/BioNTech, Sinopharm:>>{'Bahrain', 'United Arab Emirates'}
# Sinovac:>>{'Turkey', 'Brazil'}
# Moderna, Pfizer/BioNTech:>>{'Denmark', 'Czechia', 'Lithuania', 'Netherlands', 'Germany', 'United States', 'Bulgaria', 'Spain', 'Iceland', 'Canada'}
# CNBG, Sinovac:>>{'China'}
# Pfizer/BioNTech, Pifzer/BioNTech:>>{'Hungary'}
# Covaxin, Covishield:>>{'India'}
# Sinopharm:>>{'Seychelles'}
# Oxford/AstraZeneca, Pfizer/BioNTech:>>{'United Kingdom'}

# %%
# !pip install plotly
import plotly.express as px
import plotly.offline as py

vaccine_map = px.choropleth(data, locations = 'iso_code', color = 'vaccines')
vaccine_map.update_layout(height=300, margin={"r":0,"t":0,"l":0,"b":0})
vaccine_map.show()
# Out:
# Requirement already satisfied: plotly in c:\users\dell user\anaconda3\lib\site-packages (5.1.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\dell user\anaconda3\lib\site-packages (from plotly) (8.0.0)
# Requirement already satisfied: six in c:\users\dell user\anaconda3\lib\site-packages (from plotly) (1.15.0)
